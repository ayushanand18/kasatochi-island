# %% [markdown]
# # Geophysical Data Analysis
#
# In this notebook we will analysis the geophysical parameters over our spatio-temporal region of interest.

# %% [markdown]
# ### importing modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## importing data
# ### soil moisture

# %%
soilm = pd.read_csv("https://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_e6a8_14ed_11ca.csv?a_soilm[(2011-10-03T00:00:00Z):1:(2011-10-03T00:00:00Z)][(51.67489):1:(58.18522)][(-179.186):1:(179.99898)],a_vwc[(2011-10-03T00:00:00Z):1:(2011-10-03T00:00:00Z)][(51.67489):1:(58.18522)][(-179.186):1:(179.99898)],d_soilm[(2011-10-03T00:00:00Z):1:(2011-10-03T00:00:00Z)][(51.67489):1:(58.18522)][(-179.186):1:(179.99898)],d_vwc[(2011-10-03T00:00:00Z):1:(2011-10-03T00:00:00Z)][(51.67489):1:(58.18522)][(-179.186):1:(179.99898)]")

# %% [markdown]
# ### ocean climatic parameters

# %%
ocean_df = pd.read_csv("https://www.nodc.noaa.gov/archive/arc0110/0164568/1.1/data/0-data/TALK_TCO2_pCO2_GLOB_Grid_Dat.csv")

# %% [markdown]
# ### all climatic parameters

# %%
# !wget "https://www.nodc.noaa.gov/archive/arc0020/0001869/1.1/data/0-data/nodc_data.dat"
# Out:
# --2022-10-16 14:53:30--  https://www.nodc.noaa.gov/archive/arc0020/0001869/1.1/data/0-data/nodc_data.dat
# Resolving www.nodc.noaa.gov (www.nodc.noaa.gov)... 205.167.25.172, 205.167.25.171, 205.167.25.178, ...
# Connecting to www.nodc.noaa.gov (www.nodc.noaa.gov)|205.167.25.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1381532819 (1.3G)
# Saving to: ‘nodc_data.dat’
#
# nodc_data.dat       100%[===================>]   1.29G  27.1MB/s    in 49s
#
# 2022-10-16 14:54:21 (26.6 MB/s) - ‘nodc_data.dat’ saved [1381532819/1381532819]

# %%
clim_df = pd.read_table("nodc_data.dat", sep = "\s+", header=0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_17/4230611041.py in <module>
# ----> 1 clim_df = pd.read_table("nodc_data.dat", sep = "\s+", header=0)
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
